# %%
import pandas as pd
import numpy as numpy

# %%
df = pd.read_csv("/Users/himalaya/Desktop/Haryana LLM ASR/data/haryanvi-tts/metadata.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  2768 non-null   str
#  1   text       2768 non-null   str
# dtypes: str(2)
# memory usage: 552.7 KB

# %%
duplicates = df[df.duplicated(subset=['file_name'], keep=False)]

# %%
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [file_name, text]
# Index: []
